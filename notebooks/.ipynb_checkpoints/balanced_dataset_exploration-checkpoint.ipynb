# %% [markdown]
# # Balanced Dataset Exploration
#
# This notebook explores the balanced CSV file generated from the preprocessed code review dataset.
#
# It performs the following steps:
# 1. Loads the CSV file.
# 2. Displays the first 10 rows.
# 3. Samples 3 rows per class.
# 4. Analyzes the distribution of classes.
# 5. Analyzes text length with summary statistics and a histogram.
# 6. Generates a word cloud for each class.

# %% [markdown]
# ## 1. Importing Required Libraries
#
# We import the necessary libraries including `pandas`, `numpy`, `matplotlib`, and `wordcloud`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Enable inline plotting for Jupyter notebooks
# %matplotlib inline

# %% [markdown]
# ## 2. Loading the Balanced CSV Dataset
#
# We load the CSV file generated from the preprocessing script. Update the path below if necessary.

# %%
csv_file_path = "/Users/tayebekavousi/Desktop/github_sa/datasets/preprocessed/code-review-dataset-balanced.csv"
df = pd.read_csv(csv_file_path)
print("Dataset loaded successfully!")
print("Dataset shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Dataset shape: (7512, 2)

# %% [markdown]
# ## 3. Displaying the First 10 Rows
#
# The following cell prints the first 10 rows to give an initial view of the dataset.

# %%
print("Head of the dataset (10 rows):")
display(df.head(10))
# Out:
# Head of the dataset (10 rows):
#                                              message  is_toxic
# 0  ditto, but particularly in this case a user_id...         0
# 1                          this returning is useless         0
# 2  I'd call this add Reference to stay in the sam...         0
# 3  I hate to be _that_ guy, but this should proba...         0
# 4  String returned to user must be translatable, ...         0
# 5            you miss an unittest with host=fakehost         0
# 6  "n YAdvance is 0 since it is LTR (horizontal)"...         0
# 7  This is likely a dumb question, but why is an ...         0
# 8  OK, got it. I am stupid. I had to run it in th...         0
# 9  default is useless in migrations. Use server_d...         0

# %% [markdown]
# ## 4. Sampling 3 Rows from Each Class
#
# We sample 3 rows per class (based on the `is_toxic` label) to inspect representative examples.

# %%
if 'is_toxic' in df.columns:
    try:
        sample_df = df.groupby('is_toxic').apply(lambda x: x.sample(n=3, random_state=42)).reset_index(drop=True)
        print("Sample (3 rows per class):")
        display(sample_df)
    except ValueError as e:
        print("Sampling error:", e)
else:
    print("Column 'is_toxic' not found in the dataset.")
# Out:
# Sample (3 rows per class):
# /var/folders/xc/qkmv0r456dn4gsy6rfgnpns80000gn/T/ipykernel_64884/1992344006.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sample_df = df.groupby('is_toxic').apply(lambda x: x.sample(n=3, random_state=42)).reset_index(drop=True)
#                                              message  is_toxic
# 0  I think yes. Because when deleting firewall_po...         0
# 1  try_lazy_umount should be False by default to ...         0
# 2               I'm all for not using silly refs. :)         0
# 3  Still would be nice to join on this, just to m...         1
# 4  Most of this crap should be cleaned up/better ...         1
# 5                Damn it, how'd that slip through...         1

# %% [markdown]
# ## 5. Distribution Analysis of Classes
#
# We visualize the distribution of `is_toxic` classes using a bar chart.

# %%
if 'is_toxic' in df.columns:
    class_counts = df['is_toxic'].value_counts()
    
    plt.figure(figsize=(6, 4))
    class_counts.plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title("Distribution of is_toxic Classes")
    plt.xlabel("is_toxic")
    plt.ylabel("Count")
    plt.xticks(rotation=0)
    plt.show()
else:
    print("Column 'is_toxic' not found in the dataset.")

# %% [markdown]
# ## 6. Text Length Analysis
#
# We compute the word count for each message, print summary statistics (average, median, maximum, minimum), and display a histogram.

# %%
if 'message' in df.columns:
    df['word_count'] = df['message'].astype(str).apply(lambda x: len(x.split()))
    
    avg_length = df['word_count'].mean()
    median_length = df['word_count'].median()
    max_length = df['word_count'].max()
    min_length = df['word_count'].min()
    
    print("Text Length Analysis (in words):")
    print(f"Average Length: {avg_length:.2f}")
    print(f"Median Length: {median_length}")
    print(f"Maximum Length: {max_length}")
    print(f"Minimum Length: {min_length}")
    
    plt.figure(figsize=(8, 5))
    plt.hist(df['word_count'], bins=30, color='lightgreen', edgecolor='black')
    plt.title("Histogram of Message Word Counts")
    plt.xlabel("Word Count")
    plt.ylabel("Frequency")
    plt.show()
else:
    print("Column 'message' not found in the dataset.")
# Out:
# Text Length Analysis (in words):
# Average Length: 19.94
# Median Length: 13.0
# Maximum Length: 351
# Minimum Length: 1

# %% [markdown]
# ## 7. Word Cloud for Each Class
#
# We generate a word cloud for each `is_toxic` class to visualize the most common words.

# %%
if 'message' in df.columns and 'is_toxic' in df.columns:
    for class_value in df['is_toxic'].unique():
        subset_df = df[df['is_toxic'] == class_value]
        text_combined = " ".join(subset_df['message'].dropna().astype(str).tolist())
        
        wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_combined)
        
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.title(f"Word Cloud for is_toxic = {class_value}")
        plt.axis("off")
        plt.show()
else:
    print("Either 'message' or 'is_toxic' column not found in the dataset.")
